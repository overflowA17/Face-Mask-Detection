# %% [markdown]
# # Task-4: Detection of face mask (I)

# %% [markdown]
# By Anubhav Sarkar

# %% [markdown]
# ### Objective:
# * Implement a real time face mask detector.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from imutils import paths

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# ### creating list of all the images in the dataset

# %%
dataset = r'C:\Users\sarka\OneDrive\Documents\Python Scripts\Face Mask detection\Mask Dataset'
imagePaths = list(paths.list_images(dataset))
imagePaths
# Out:
# ['C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\0.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\1.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\10.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\100.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\101.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\102.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\104.jpg',
#  'C:\\Users\\sarka\\OneDrive\\Documents\\Python Scripts\\Face Mask detection\\Mask Dataset\\without_mask\\105.jpg',
# ...

# %%
data=[]
labels=[]

for i in imagePaths:
    label=i.split(os.path.sep)[-2]
    labels.append(label)
    image=load_img(i,target_size=(224,224))
    image=img_to_array(image)
    image=preprocess_input(image)
    data.append(image)
data
# Out:
# [array([[[-0.94509804, -0.9764706 , -0.85882354],
#          [-0.94509804, -0.9764706 , -0.85882354],
#          [-0.94509804, -0.9764706 , -0.85882354],
#          ...,
#          [-0.8509804 , -0.90588236, -0.78039217],
#          [-0.8509804 , -0.90588236, -0.78039217],
#          [-0.84313726, -0.8980392 , -0.77254903]],
#
#         [[-0.9137255 , -0.94509804, -0.827451  ],
#          [-0.9137255 , -0.94509804, -0.827451  ],
#          [-0.9137255 , -0.94509804, -0.827451  ],
#          ...,
#          [-0.7647059 , -0.79607844, -0.6784314 ],
#          [-0.7647059 , -0.79607844, -0.6784314 ],
#          [-0.75686276, -0.7882353 , -0.67058825]],
#
#         [[-0.92156863, -0.9607843 , -0.8039216 ],
#          [-0.92156863, -0.9607843 , -0.8039216 ],
#          [-0.92156863, -0.9607843 , -0.8039216 ],
#          ...,
#          [-0.88235295, -0.8980392 , -0.7882353 ],
#          [-0.8666667 , -0.88235295, -0.77254903],
#          [-0.85882354, -0.8745098 , -0.7647059 ]],
#
# ...

# %%
image
# Out:
# array([[[ 0.6784314 ,  0.62352943,  0.48235297],
#         [ 0.6627451 ,  0.62352943,  0.47450984],
#         [ 0.654902  ,  0.6156863 ,  0.4666667 ],
#         ...,
#         [ 0.75686276,  0.64705884,  0.5764706 ],
#         [ 0.77254903,  0.67058825,  0.6       ],
#         [ 0.75686276,  0.6392157 ,  0.58431375]],
#
#        [[ 0.6627451 ,  0.60784316,  0.4666667 ],
#         [ 0.6627451 ,  0.6156863 ,  0.4901961 ],
#         [ 0.67058825,  0.6156863 ,  0.4901961 ],
#         ...,
#         [ 0.78039217,  0.6784314 ,  0.60784316],
#         [ 0.75686276,  0.654902  ,  0.58431375],
#         [ 0.75686276,  0.654902  ,  0.5921569 ]],
#
#        [[ 0.6627451 ,  0.60784316,  0.48235297],
#         [ 0.67058825,  0.62352943,  0.49803925],
#         [ 0.64705884,  0.5921569 ,  0.4666667 ],
#         ...,
#         [ 0.78039217,  0.67058825,  0.6       ],
#         [ 0.7647059 ,  0.6627451 ,  0.5921569 ],
#         [ 0.78039217,  0.67058825,  0.6       ]],
#
#        ...,
#
# ...

# %%
labels
# Out:
# ['without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
#  'without_mask',
# ...

# %% [markdown]
# ####  Turning the data into a numpy array

# %%
data=np.array(data,dtype='float32')
labels=np.array(labels)

# %%
data
# Out:
# array([[[[-0.94509804, -0.9764706 , -0.85882354],
#          [-0.94509804, -0.9764706 , -0.85882354],
#          [-0.94509804, -0.9764706 , -0.85882354],
#          ...,
#          [-0.8509804 , -0.90588236, -0.78039217],
#          [-0.8509804 , -0.90588236, -0.78039217],
#          [-0.84313726, -0.8980392 , -0.77254903]],
#
#         [[-0.9137255 , -0.94509804, -0.827451  ],
#          [-0.9137255 , -0.94509804, -0.827451  ],
#          [-0.9137255 , -0.94509804, -0.827451  ],
#          ...,
#          [-0.7647059 , -0.79607844, -0.6784314 ],
#          [-0.7647059 , -0.79607844, -0.6784314 ],
#          [-0.75686276, -0.7882353 , -0.67058825]],
#
#         [[-0.92156863, -0.9607843 , -0.8039216 ],
#          [-0.92156863, -0.9607843 , -0.8039216 ],
#          [-0.92156863, -0.9607843 , -0.8039216 ],
#          ...,
#          [-0.88235295, -0.8980392 , -0.7882353 ],
#          [-0.8666667 , -0.88235295, -0.77254903],
#          [-0.85882354, -0.8745098 , -0.7647059 ]],
#
# ...

# %%
data.shape
# Out:
# (1376, 224, 224, 3)

# %%
labels
# Out:
# array(['without_mask', 'without_mask', 'without_mask', ..., 'with_mask',
#        'with_mask', 'with_mask'], dtype='<U12')

# %%
lb=LabelBinarizer()
labels=lb.fit_transform(labels)
labels=to_categorical(labels)
labels
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# ### Splitting the data

# %%
train_X,test_X,train_Y,test_Y=train_test_split(data,labels,test_size=0.20,stratify=labels,random_state=10)

# %%
train_X.shape
# Out:
# (1100, 224, 224, 3)

# %%
train_Y.shape
# Out:
# (1100, 2)

# %% [markdown]
# #### image data generator

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.15, width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,horizontal_flip=True,vertical_flip=True, fill_mode='nearest')

# %% [markdown]
# ### Data Modelling

# %%
baseModel = MobileNetV2(weights = 'imagenet',include_top=False, input_tensor=Input(shape = (224,224,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
baseModel.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
headModel=baseModel.output
headModel=AveragePooling2D(pool_size=(7,7))(headModel)
headModel=Flatten(name='Flatten')(headModel)
headModel=Dense(128,activation='relu')(headModel)
headModel=Dropout(0.5)(headModel)
headModel=Dense(2,activation='softmax')(headModel)

model=Model(inputs=baseModel.input,outputs=headModel)

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %% [markdown]
# ### Training and Saving The Data

# %%
learning_rate=0.001
Epochs=20
BS=12

opt=Adam(lr=learning_rate,decay=learning_rate/Epochs)
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=['accuracy'])

H=model.fit(
    aug.flow(train_X,train_Y,batch_size=BS),
    steps_per_epoch=len(train_X)//BS,
    validation_data=(test_X,test_Y),
    validation_steps=len(test_X)//BS,
    epochs=Epochs
)


model.save(r'C:\Users\sarka\OneDrive\Documents\Python Scripts\Face Mask detection\Model.model')
# Out:
# Epoch 1/20
# 91/91 [==============================] - 52s 507ms/step - loss: 0.4046 - accuracy: 0.8176 - val_loss: 0.0595 - val_accuracy: 0.9819
# Epoch 2/20
# 91/91 [==============================] - 51s 560ms/step - loss: 0.0786 - accuracy: 0.9716 - val_loss: 0.0472 - val_accuracy: 0.9819
# Epoch 3/20
# 91/91 [==============================] - 49s 537ms/step - loss: 0.0622 - accuracy: 0.9807 - val_loss: 0.0432 - val_accuracy: 0.9819
# Epoch 4/20
# 91/91 [==============================] - 49s 535ms/step - loss: 0.0633 - accuracy: 0.9798 - val_loss: 0.0457 - val_accuracy: 0.9819
# Epoch 5/20
# 91/91 [==============================] - 50s 548ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.0474 - val_accuracy: 0.9783
# Epoch 6/20
# 91/91 [==============================] - 52s 575ms/step - loss: 0.0233 - accuracy: 0.9915 - val_loss: 0.0458 - val_accuracy: 0.9783
# Epoch 7/20
# ...

# %% [markdown]
# ### plot the training loss and accuracy

# %%
N = Epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
